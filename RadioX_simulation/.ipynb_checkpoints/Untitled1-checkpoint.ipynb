# %%
import numpy as np
import astropy
import scipy.stats as st

class X_lum(rv_discrete):
     def _pmf(self, k, mu):
        return exp(-mu) * mu**k / factorial(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-363-e5113130c965> in <module>
#       3 import scipy.stats as st
#       4
# ----> 5 class X_lum(rv_discrete):
#       6      def _pmf(self, k, mu):
#       7         return exp(-mu) * mu**k / factorial(k)
#
# NameError: name 'rv_discrete' is not defined
